# %%
from onnx import load
import onnxruntime as rt
import numpy as np
import pandas as pd
import sys
np.set_printoptions(threshold=sys.maxsize)

# %%
with open("model_without_other.onnx", "rb") as f:
    onnx_model = load(f)

# %%
#print(onnx_model)

# %%
sess = rt.InferenceSession("model_without_other.onnx")

# %%
input_name = sess.get_inputs()[0].name
print("input name", input_name)
input_shape = sess.get_inputs()[0].shape
print("input shape", input_shape)
input_type = sess.get_inputs()[0].type
print("input type", input_type)
# Out:
# input name dense_input
# input shape ['unk__6', 60]
# input type tensor(float)

# %%
output_name = sess.get_outputs()[0].name
print("output name", output_name)
output_shape = sess.get_outputs()[0].shape
print("output shape", output_shape)
output_type = sess.get_outputs()[0].type
print("output type", output_type)
# Out:
# output name dense_1
# output shape ['unk__7', 2]
# output type tensor(float)

# %%
symbol_data = pd.read_csv("runesheet.csv", header=None)
X = symbol_data.iloc[:, :-1]
Y = symbol_data.iloc[:,-1:]
Y = Y.replace("Time", 0)
Y = Y.replace("Wind", 1)

# %%
print(sess.run([output_name], {input_name: np.array(X).astype(np.float32)}))
# Out:
# [array([[9.99934196e-01, 6.57731944e-05],
#        [9.99980330e-01, 1.97149420e-05],
#        [9.99966145e-01, 3.37972124e-05],
#        [9.99922514e-01, 7.74933869e-05],
#        [9.99969482e-01, 3.05324393e-05],
#        [9.99723971e-01, 2.76066305e-04],
#        [9.99990463e-01, 9.55461837e-06],
#        [9.99893308e-01, 1.06707004e-04],
#        [9.99974608e-01, 2.53505805e-05],
#        [9.99706924e-01, 2.93083780e-04],
#        [9.99973178e-01, 2.68285476e-05],
#        [9.99976873e-01, 2.31416616e-05],
#        [9.99992013e-01, 8.00489943e-06],
#        [9.99992013e-01, 8.01427996e-06],
#        [9.99992490e-01, 7.46975593e-06],
#        [9.99988198e-01, 1.18368043e-05],
#        [9.99919653e-01, 8.03529983e-05],
#        [9.99786317e-01, 2.13643361e-04],
#        [9.99979615e-01, 2.03984018e-05],
#        [9.99948382e-01, 5.16192231e-05],
#        [9.99957561e-01, 4.24923128e-05],
#        [9.99947906e-01, 5.20472749e-05],
#        [9.99987245e-01, 1.27682815e-05],
# ...

# %%
sess = rt.InferenceSession("model_with_other.onnx")
output_name = sess.get_outputs()[0].name

# %%
print(sess.run([output_name], {input_name: np.array(X).astype(np.float32)}))
# Out:
# [array([[9.98638093e-01, 1.14912801e-10, 1.36191025e-03],
#        [9.97551978e-01, 1.74038159e-10, 2.44801212e-03],
#        [9.99438941e-01, 5.83870383e-11, 5.61020512e-04],
#        [9.99422431e-01, 1.53740590e-10, 5.77577623e-04],
#        [9.98171926e-01, 1.96186643e-11, 1.82801601e-03],
#        [9.96332765e-01, 3.81391700e-08, 3.66726471e-03],
#        [9.99792874e-01, 6.35222343e-12, 2.07188335e-04],
#        [9.96467471e-01, 6.06216119e-11, 3.53253772e-03],
#        [9.98123467e-01, 3.08206824e-12, 1.87649706e-03],
#        [9.98111486e-01, 8.19680573e-11, 1.88849843e-03],
#        [9.99537468e-01, 9.37380729e-12, 4.62600088e-04],
#        [9.98393238e-01, 1.93551182e-11, 1.60679489e-03],
#        [8.44445109e-01, 1.87400460e-08, 1.55554906e-01],
#        [9.75296855e-01, 2.83633464e-11, 2.47031581e-02],
#        [9.99948025e-01, 1.84586959e-12, 5.19259120e-05],
#        [9.99088764e-01, 1.65136845e-11, 9.11233539e-04],
# ...
